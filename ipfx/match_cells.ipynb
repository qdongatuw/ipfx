# 47              NaN              NaN              NaN              NaN
# 48              NaN              NaN              NaN              NaN
# 49              NaN              NaN              NaN              NaN
# 50  2023_03_27_0128              NaN              NaN              NaN
# 51              NaN              NaN              NaN              NaN
# 52              NaN              NaN              NaN              NaN
# 53              NaN              NaN              NaN              NaN
# 54              NaN              NaN              NaN              NaN
# 55  2023_03_27_0152              NaN              NaN              NaN
# 56  2023_03_27_0159              NaN              NaN              NaN
# 57  2023_03_27_0166  2023_03_27_0167              NaN              NaN
#
#         Unnamed: 14      Unnamed: 15
# 0               NaN              NaN
# 1   2023_04_01_0018              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN
# 11              NaN              NaN
# 12              NaN              NaN
# 13  2023_04_01_0100  2023_04_01_0101
# 14              NaN              NaN
# 15              NaN              NaN
# 16              NaN              NaN
# 17              NaN              NaN
# 18              NaN              NaN
# 19              NaN              NaN
# 20              NaN              NaN
# 21              NaN              NaN
# 22              NaN              NaN
# 23              NaN              NaN
# 24              NaN              NaN
# 25              NaN              NaN
# 26              NaN              NaN
# 27              NaN              NaN
# 28              NaN              NaN
# 29              NaN              NaN
# 30              NaN              NaN
# 31              NaN              NaN
# 32              NaN              NaN
# 33              NaN              NaN
# 34              NaN              NaN
# 35              NaN              NaN
# 36              NaN              NaN
# 37              NaN              NaN
# 38              NaN              NaN
# 39              NaN              NaN
# 40              NaN              NaN
# 41              NaN              NaN
# 42              NaN              NaN
# 43              NaN              NaN
# 44              NaN              NaN
# 45              NaN              NaN
# 46              NaN              NaN
# 47              NaN              NaN
# 48              NaN              NaN
# 49              NaN              NaN
# 50              NaN              NaN
# 51              NaN              NaN
# 52              NaN              NaN
# 53              NaN              NaN
# 54              NaN              NaN
# 55              NaN              NaN
# 56              NaN              NaN
# 57              NaN              NaN

# %%
data_dict = {}

# 遍历DataFrame的每一行
for index, row in df_list.iterrows():
    # 提取ID和测试结果列
    sample_id = row.iloc[0]
    genotype = row.iloc[3]
    results = row.iloc[4:].tolist()  # 将测试结果转换为列表
    data_dict[sample_id] = dict()

    data_dict[sample_id]['genotype'] = genotype
    data_dict[sample_id]['files'] = []
    # 将测试结果添加到字典中相应的ID键下的值列表中
    results_filtered = [result for result in results if pd.notna(result)]
    if sample_id in data_dict:
        data_dict[sample_id]['files'].extend(results_filtered)

# %%
raw_dict = df_raw.to_dict(orient='records')

# %%
str(raw_dict[0]['-1000.0 pA']) == 'nan'
# Out:
# True

# %%
raw_dict_key_file = dict()
for record in raw_dict:
    raw_dict_key_file[record['File']] = record

# %%
summary_dict = dict()
for cell in data_dict:
    summary_dict[cell] = dict()
    files = data_dict[cell]['files']
    for k in files:
        file = k + '.abf'
        if file in raw_dict_key_file:
            result = raw_dict_key_file[file]
            for i in result:
                if str(result[i]) != 'nan' and i not in summary_dict[cell]:

                    summary_dict[cell][i] = result[i]

# %%
df_summary = pd.DataFrame(summary_dict)

# %%
df_summary.T.to_csv('summary.csv')
